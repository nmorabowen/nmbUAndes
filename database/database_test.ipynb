# %%
import sqlite3

# %%
# Create the database
conn=sqlite3.connect('test.db')

# Call the crusor to execute commands
c=conn.cursor()

# Create the database table
c.execute("""CREATE TABLE modelInfo (
            id datatype PRIMARY KEY,
            fileName datatype TEXT,
            date datatype TEXT,
            runTime datatype REAL,
            )
          """)
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# Cell In[12], line 8
#       5 c=conn.cursor()
#       7 # Create the database table
# ----> 8 c.execute("""CREATE TABLE analysis_commands (
#       9             id datatype PRIMARY KEY,
#      10             fileName datatype TEXT
#      11             )
#      12           """)
#
# OperationalError: table analysis_commands already exists
